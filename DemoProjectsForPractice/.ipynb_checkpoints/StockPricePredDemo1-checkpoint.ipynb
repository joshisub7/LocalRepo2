# %%
import numpy as np
#from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from tensorflow.keras import Sequential
import pandas as pd
from sklearn.preprocessing import StandardScaler
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 #from keras.models import Sequential
# ----> 3 from keras.layers import LSTM
#       4 from keras.layers import Dense
#       5 from tensorflow.keras import Sequential
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\keras\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\keras\__internal__\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\keras\__internal__\backend\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.src.backend import _initialize_variables as initialize_variables
#       4 from keras.src.backend import track_variable
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\keras\src\__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras.src import distribute
# ---> 21 from keras.src import models
#      22 from keras.src.engine.input_layer import Input
#      23 from keras.src.engine.sequential import Sequential
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\keras\src\models\__init__.py:18
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.src.engine.functional import Functional
#      19 from keras.src.engine.sequential import Sequential
#      20 from keras.src.engine.training import Model
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\keras\src\engine\functional.py:23
#      20 import itertools
#      21 import warnings
# ---> 23 import tensorflow.compat.v2 as tf
#      25 from keras.src import backend
#      26 from keras.src.dtensor import layout_map as layout_map_lib
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\__init__.py:38
#      35 import sys as _sys
#      36 import typing as _typing
# ---> 38 from tensorflow.python.tools import module_util as _module_util
#      39 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      41 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\__init__.py:37
#      29 # We aim to keep this file minimal and ideally remove completely.
#      30 # If you are adding a new file with @tf_export decorators,
#      31 # import it in modules_with_exports.py instead.
#      32
#      33 # go/tf-wildcard-import
#      34 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
#      42 from tensorflow.python import data
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\eager\context.py:36
#      34 from tensorflow.python.client import pywrap_tf_session
#      35 from tensorflow.python.eager import cancellation
# ---> 36 from tensorflow.python.eager import execute
#      37 from tensorflow.python.eager import executor
#      38 from tensorflow.python.eager import monitoring
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\eager\execute.py:21
#      19 from tensorflow.python import pywrap_tfe
#      20 from tensorflow.python.eager import core
# ---> 21 from tensorflow.python.framework import dtypes
#      22 from tensorflow.python.framework import tensor_conversion_registry
#      23 from tensorflow.python.framework import tensor_shape
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:732
#     658     _NP_TO_TF[pdt] = next(
#     659         _NP_TO_TF[dt] for dt in _NP_TO_TF if dt == pdt().dtype)  # pylint: disable=no-value-for-parameter
#     661 TF_VALUE_DTYPES = set(_NP_TO_TF.values())
#     663 _TF_TO_NP = {
#     664     types_pb2.DT_HALF:
#     665         np.float16,
#     666     types_pb2.DT_FLOAT:
#     667         np.float32,
#     668     types_pb2.DT_DOUBLE:
#     669         np.float64,
#     670     types_pb2.DT_INT32:
#     671         np.int32,
#     672     types_pb2.DT_UINT8:
#     673         np.uint8,
#     674     types_pb2.DT_UINT16:
#     675         np.uint16,
#     676     types_pb2.DT_UINT32:
#     677         np.uint32,
#     678     types_pb2.DT_UINT64:
#     679         np.uint64,
#     680     types_pb2.DT_INT16:
#     681         np.int16,
#     682     types_pb2.DT_INT8:
#     683         np.int8,
#     684     # NOTE(touts): For strings we use object as it supports variable length
#     685     # strings.
#     686     types_pb2.DT_STRING:
#     687         object,
#     688     types_pb2.DT_COMPLEX64:
#     689         np.complex64,
#     690     types_pb2.DT_COMPLEX128:
#     691         np.complex128,
#     692     types_pb2.DT_INT64:
#     693         np.int64,
#     694     types_pb2.DT_BOOL:
#     695         np.bool_,
#     696     types_pb2.DT_QINT8:
#     697         _np_qint8,
#     698     types_pb2.DT_QUINT8:
#     699         _np_quint8,
#     700     types_pb2.DT_QINT16:
#     701         _np_qint16,
#     702     types_pb2.DT_QUINT16:
#     703         _np_quint16,
#     704     types_pb2.DT_QINT32:
#     705         _np_qint32,
#     706     types_pb2.DT_BFLOAT16:
#     707         _np_bfloat16,
#     708     types_pb2.DT_FLOAT8_E5M2:
#     709         _np_float8_e5m2,
#     710     types_pb2.DT_FLOAT8_E4M3FN:
#     711         _np_float8_e4m3fn,
#     712     # Ref types
#     713     types_pb2.DT_HALF_REF:
#     714         np.float16,
#     715     types_pb2.DT_FLOAT_REF:
#     716         np.float32,
#     717     types_pb2.DT_DOUBLE_REF:
#     718         np.float64,
#     719     types_pb2.DT_INT32_REF:
#     720         np.int32,
#     721     types_pb2.DT_UINT32_REF:
#     722         np.uint32,
#     723     types_pb2.DT_UINT8_REF:
#     724         np.uint8,
#     725     types_pb2.DT_UINT16_REF:
#     726         np.uint16,
#     727     types_pb2.DT_INT16_REF:
#     728         np.int16,
#     729     types_pb2.DT_INT8_REF:
#     730         np.int8,
#     731     types_pb2.DT_STRING_REF:
# --> 732         object_,
#     733     types_pb2.DT_COMPLEX64_REF:
#     734         np.complex64,
#     735     types_pb2.DT_COMPLEX128_REF:
#     736         np.complex128,
#     737     types_pb2.DT_INT64_REF:
#     738         np.int64,
#     739     types_pb2.DT_UINT64_REF:
#     740         np.uint64,
#     741     types_pb2.DT_BOOL_REF:
#     742         np.bool_,
#     743     types_pb2.DT_QINT8_REF:
#     744         _np_qint8,
#     745     types_pb2.DT_QUINT8_REF:
#     746         _np_quint8,
#     747     types_pb2.DT_QINT16_REF:
#     748         _np_qint16,
#     749     types_pb2.DT_QUINT16_REF:
#     750         _np_quint16,
#     751     types_pb2.DT_QINT32_REF:
#     752         _np_qint32,
#     753     types_pb2.DT_BFLOAT16_REF:
#     754         _np_bfloat16,
#     755     types_pb2.DT_FLOAT8_E5M2_REF:
#     756         _np_float8_e5m2,
#     757     types_pb2.DT_FLOAT8_E4M3FN_REF:
#     758         _np_float8_e4m3fn,
#     759 }
#     761 _QUANTIZED_DTYPES_NO_REF = frozenset([qint8, quint8, qint16, quint16, qint32])
#     762 _QUANTIZED_DTYPES_REF = frozenset(
#     763     [qint8_ref, quint8_ref, qint16_ref, quint16_ref, qint32_ref])
#
# NameError: name 'object_' is not defined

# %% [markdown]
# #!pip install pandas--> (!pip install) is used to install any packages

# %%
#!pip install tensorflow

# %%
pip install h5py pip install typing-extensions pip install wheel
# Out:
# Requirement already satisfied: h5py in c:\users\acer\anaconda3\envs\tensorflow\lib\site-packages (2.10.0)
# Requirement already satisfied: pip in c:\users\acer\anaconda3\envs\tensorflow\lib\site-packages (23.3.1)
# Requirement already satisfied: install in c:\users\acer\anaconda3\envs\tensorflow\lib\site-packages (1.3.5)
# Requirement already satisfied: typing-extensions in c:\users\acer\anaconda3\envs\tensorflow\lib\site-packages (4.9.0)
# Requirement already satisfied: wheel in c:\users\acer\anaconda3\envs\tensorflow\lib\site-packages (0.41.2)
# Requirement already satisfied: numpy>=1.7 in c:\users\acer\anaconda3\envs\tensorflow\lib\site-packages (from h5py) (1.24.4)
# Requirement already satisfied: six in c:\users\acer\anaconda3\envs\tensorflow\lib\site-packages (from h5py) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in c:\users\acer\anaconda3\envs\tensorflow\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\acer\anaconda3\envs\tensorflow\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acer\anaconda3\envs\tensorflow\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\acer\anaconda3\envs\tensorflow\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\acer\anaconda3\envs\tensorflow\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in c:\users\acer\anaconda3\envs\tensorflow\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
#import numpy
#print (numpy.__version__)

# %%
# !pip install --upgrade tensorflow

# %%
# !pip install --upgrade numpy
